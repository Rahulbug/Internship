# %% [markdown]
# # Web_scraping with Selenium

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.

# %%
#first we will install required libraries

# %%
# !pip install selenium

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Banglore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping location

location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scpaing company name

company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping expirence required

experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'exp_required':experience_required})

# %%
df
# Out:
#                                            job_title  \
# 0                                Senior Data Analyst
# 1                                       Data Analyst
# 2  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 3  Call For Clinical Data Analyst - Hyd/Bangalore...
# 4                Payroll Transformation Data Analyst
# 5                                    HR Data Analyst
# 6                                Senior Data Analyst
# 7                          Sr. SAP Hana Data Analyst
# 8    Business Execution (Data and Reporting Analyst)
# 9                                       Data Analyst
#
#                                         job_location  \
# 0                       Chennai, Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2  Kolkata, Hyderabad/Secunderabad, Pune, Bangalo...
# 3  Kolkata, Hyderabad/Secunderabad, Pune, Bangalo...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Banglore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping location

location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scpaing company name

company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping expirence required

experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'exp_required':experience_required})

# %%
df
# Out:
#                                            job_title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Analystics & Modeling Specialist
# 4                   Assistant Manager - Data Science
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                              Senior Data Scientist
# 8            Data Scientist: Artificial Intelligence
# 9                   Data Scientist - Computer Vision
#
#                                         job_location             company_name  \
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...                Accenture
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...                Accenture
# 2  Hyderabad/Secunderabad, Pune, Chennai, Bangalo...                  Mphasis
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage
#     You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Delhi/NCR')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
                                

    
location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(experience_required),len(job_location))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                                            job_title  \
# 0  Mongodb Database Administrator, Maria DB or Ca...
# 1                   Analystics & Modeling Specialist
# 2                                     Data Scientist
# 3                              Senior Data Scientist
# 4  Opportunity For Senior Data Scientist/ Busines...
# 5  Exciting opportunity For model monitoring/mode...
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                 Data Scientist: Advanced Analytics
# 9  ACN - Applied Intelligence - Data & Insights -...
#
#                                         job_location             company_name  \
# 0  Delhi / NCR, Hyderabad/Secunderabad, Pune, Che...                  Mphasis
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...                Accenture
# 2  Delhi / NCR, New Delhi, Pune, Gurgaon/Gurugram...            ZS Associates
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver = webdriver.Edge(executable_path = "C://Users//Rahul//Documents//edgedriver_win64//msedgedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search_feild_designation=driver.find_element(By.CLASS_NAME,"_3704LK")
search_feild_designation.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
fp_brand =[]
fp_description=[]
fp_price=[]

# %%
brand_tag=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
for i in brand_tag[0:40]:
    brand=i.text
    fp_brand.append(brand)
    
description_tag=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
for i in description_tag[0:40]:
    descr=i.text
    fp_description.append(descr)
    
price_tag=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
for i in price_tag[0:40]:
    price=i.text
    fp_price.append(price)

# %%
print(len(fp_brand),len(fp_description),len(fp_price))
# Out:
# 40 40 40

# %%
import pandas as pd

# %%
df=pd.DataFrame({'fp_brand':fp_brand,'fp_description':fp_description,'fp_price':fp_price})

# %%
df
# Out:
#              fp_brand                                     fp_description  \
# 0            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 1   SHAAH COLLECTIONS                UV Protection Round Sunglasses (54)
# 2          LIZA ANGEL      UV Protection Wayfarer Sunglasses (Free Size)
# 3   SHAAH COLLECTIONS   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 4                MODE       UV Protection Aviator Sunglasses (Free Size)
# 5              PIRASO              UV Protection Aviator Sunglasses (54)
# 6   SHAAH COLLECTIONS              UV Protection Aviator Sunglasses (54)
# 7              SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 8              PIRASO              UV Protection Aviator Sunglasses (58)
# 9   SHAAH COLLECTIONS   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 10             PIRASO          UV Protection Rectangular Sunglasses (52)
# 11      VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# ...

# %%
#NEXT PAGE

# %%
next_page=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span")
next_page.click()

# %%
fp_brand=[]
fp_description=[]
fp_price=[]

# %%
brand_tag=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
for i in brand_tag[0:40]:
    brand=i.text
    fp_brand.append(brand)
    
description_tag=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
for i in description_tag[0:40]:
    descr=i.text
    fp_description.append(descr)
    
price_tag=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")    
for i in price_tag[0:40]:
    price=i.text
    fp_price.append(price)

# %%
print(len(fp_brand),len(fp_description),len(fp_price))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'fp_brand':fp_brand,'fp_description':fp_description,'fp_price':fp_price})

# %%
df
# Out:
#              fp_brand                                     fp_description  \
# 0           ROYAL SON                   Mirrored Aviator Sunglasses (55)
# 1       VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...
# 2                IDEE              UV Protection Aviator Sunglasses (58)
# 3            Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 4           New Specs  Mirrored, UV Protection, Riding Glasses, Other...
# 5           ROYAL SON  Polarized, UV Protection Wayfarer Sunglasses (61)
# 6           ROYAL SON  UV Protection, Gradient Butterfly Sunglasses (62)
# 7   SHAAH COLLECTIONS                UV Protection Round Sunglasses (52)
# 8                IDEE    Gradient, UV Protection Aviator Sunglasses (58)
# 9                IDEE             UV Protection Wayfarer Sunglasses (18)
# 10      VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# 11             PIRASO             UV Protection Wayfarer Sunglasses (55)
# ...

# %%
#NEXT PAGE

# %%
next_page1=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span")
next_page1.click()

# %%
fp_brand=[]
fp_description=[]
fp_price=[]

# %%
brand_tag=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
for i in brand_tag[0:20]:
    brand=i.text
    fp_brand.append(brand)
    
description_tag=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
for i in description_tag[0:20]:
    descr=i.text
    fp_description.append(descr)
    
price_tag=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
for i in price_tag[0:20]:
    price=i.text
    fp_price.append(price)

# %%
print(len(fp_brand),len(fp_description),len(fp_price))
# Out:
# 20 20 20

# %%
df=pd.DataFrame({'fp_brand':fp_brand,'fp_description':fp_description,'fp_price':fp_price})

# %%
df
# Out:
#              fp_brand                                     fp_description  \
# 0       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 1            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 2              PIRASO           UV Protection Over-sized Sunglasses (65)
# 3            Fastrack        UV Protection Sports Sunglasses (Free Size)
# 4                  Mi           Polarized Aviator Sunglasses (Free Size)
# 5       VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...
# 6      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 7           ROYAL SON              Polarized Rectangular Sunglasses (60)
# 8               NuVew     UV Protection, Mirrored Sports Sunglasses (62)
# 9      kingsunglasses         UV Protection Round Sunglasses (Free Size)
# 10               IDEE           UV Protection Over-sized Sunglasses (57)
# 11      VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# ...

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.
# This task will be done in following steps:
# 1. First get the webpage https://www.flipkart.com/
# 2. Enter “iphone 11” in “Search” field .
# 3. Then click the search button
# As shown in the above page you have to scrape the tick marked attributes.These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search_feild_designation=driver.find_element(By.CLASS_NAME,"_3704LK")
search_feild_designation.send_keys('iphone 11')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
Rating = []
Review_summary = []
Full_review = []

rating = driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']")
review = driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
full_review = driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']")

#for page in range(0,3):
for i in rating:
    Rating.append(i.text)
for o in review:
    Review_summary.append(o.text)
for p in full_review:
    Full_review.append(p.text)    
    
df = pd.DataFrame({'Rating':rating,'Review_summary':review,'Full_review':full_review})

#df
# Out:
# Empty DataFrame
# Columns: [Rating, Review_summary, Full_review]
# Index: []

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
search_feild_designation=driver.find_element(By.CLASS_NAME,"_3704LK")
search_feild_designation.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
Brand = []
Product_Description = []
Price = []

for i in range(3):
    
    
    brand = driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    product_des = driver.find_elements(By.XPATH,"//div[@class='_2B099V']/a[1]")
    price = driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")


    for i in brand:
        Brand.append(i.text)
    for i in product_des:
        Product_Description.append(i.text)
    for i in price :
        Price.append(i.text)
    
time.sleep(3)

nxt_button = driver.find_element(By.XPATH,"//a[@class='_1LKTO3']")
nxt_button.click()

# %%
print(len(Brand),len(Product_Description),len(Price))
# Out:
# 120 120 120

# %%
df = pd.DataFrame({'Brand':Brand,'Product_Description':Product_Description,'Price':Price})

df[0:100]
# Out:
#                   Brand                                Product_Description  \
# 0                Layasa                                   Sneakers For Men
# 1              RapidBox                                   Sneakers For Men
# 2                BRUTON               Modern Trendy Shoes Sneakers For Men
# 3                Labbin                                   Sneakers For Men
# 4                BRUTON  Lightweight Pack Of 1 Trendy Sneakers Sneakers...
# ..                  ...                                                ...
# 95               Zavier                                   Sneakers For Men
# 96             Magnolia                                   Sneakers For Men
# 97            Deals4you                                 Sneakers For Women
# 98  World Wear Footwear  Latest Collection Black-349 Trendy & Stylish C...
# 99                 PUMA                Court Star Vulc FS Sneakers For Men
#
#      Price
# 0     ₹497
# 1     ₹590
# 2     ₹470
# 3     ₹499
# ...

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes
# Set second Price filter and Color filter to “Black”, as shown in the below image.

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get("http://www.myntra.com/shoes")

# %%
color_filter = driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
color_filter.click()
time.sleep(3)

# %%
price_filter = driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
price_filter.click()
time.sleep(3)

# %%
Brand = []
Shoe_des = []
price = []

for i in range(2):
    
    brand = driver.find_elements(By.XPATH,"//h3[@class='product-brand']")
    shoe_des = driver.find_elements(By.XPATH,"//h4[@class='product-product']")
    price = driver.find_elements(By.XPATH,"//div[@class='product-price']/span[1]")


    for i in brand : Brand.append(i.text)
    for i in shoe_des: Shoe_des.append(i.text)
    for i in price : price.append(i.text)
time.sleep(3)

next_page = driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[12]/a")

next_page.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 5>()
#      12     for i in brand : Brand.append(i.text)
#      13     for i in shoe_des: Shoe_des.append(i.text)
# ---> 14     for i in price : price.append(i.text)
#      15 time.sleep(3)
#      17 next_page = driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[12]/a")
#
# AttributeError: 'str' object has no attribute 'text'

# %% [markdown]
# Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
search_item = driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute']")
search_item.send_keys("laptop")

# %%
click_search_button = driver.find_element(By.XPATH,"//input[@id='nav-search-submit-button']")
click_search_button.click()

# %%
inte_core7=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[5]/li[11]/span/a")
intel_core7.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [75], in <cell line: 2>()
#       1 inte_core7=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[5]/li[11]/span/a")
# ----> 2 intel_core7.click()
#
# AttributeError: 'list' object has no attribute 'click'

# %% [markdown]
# Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary

# %%
driver = webdriver.Edge(executable_path = "C:\\Users\\Rahul\\Documents\\edgedriver_win64\\msedgedriver.exe")

# %%
driver.get("http://www.ambitionbox.com/")

# %%
search=driver.find_elements(By.XPATH,"//a[@class='navItemLink']")
search.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [92], in <cell line: 2>()
#       1 search=driver.find_elements(By.XPATH,"//a[@class='navItemLink']")
# ----> 2 search.click()
#
# AttributeError: 'list' object has no attribute 'click'
